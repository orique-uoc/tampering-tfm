# %% [markdown]
# **NOTES**
#
# Using this notebook with CASIAv2.0 dataset requires a runtime with at least 64GB of system RAM and 32GB of disk. If you are running this in Google Colab, it might require a **paid** subscription. With a v2-8 TPU runtime, it took around 12 hours (or 21.12 compute units) to run the whole notebook. This may result in a direct cost around 2 to 3 EUR as of 4th January 2025.
#
# Before execution, review carefully all paths. This notebook expects to have all npy files already generated. In order to generate them, please use the provided dedicated notebook.
#
# As we did the work with tensorflow 2.15.0 we are forcing that version to ensure no compatibility issues appear. It might not be strictly necessary to stick to that version, though.
#
# This notebook is structured in three sections. One that is common for both the binary classifier and for the localizer, which loads the required data into memory, and then one section for each model.

# %% [markdown]
# **COMMON FOR BINARY CLASSIFIER AND LOCALIZER**

# %%
# !pip install tensorflow==2.15.0
# Out:
# Requirement already satisfied: tensorflow==2.15.0 in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (1.68.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.15.0) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.15.0) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow==2.15.0) (3.2.2)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
CNN_AUTHENTIC_DIRECTORY = '/content/gdrive/MyDrive/TFM/datasets/CASIA2/Au'
CNN_TAMPERED_DIRECTORY = '/content/gdrive/MyDrive/TFM/datasets/CASIA2/Tp'
CNN_GROUND_TRUTH_DIRECTORY = '/content/gdrive/MyDrive/TFM/datasets/CASIA2/gt_all_grayscale'
AUGMENTED_MASK_DIRECTORY = CNN_GROUND_TRUTH_DIRECTORY + "/augment"

# %%
def get_npy_directory(directory):
    return directory + '/npy'

def get_npy_file(directory, file):
    return get_npy_directory(directory) + '/' + file + '.npy'

def get_npy_authentic_file():
    return get_npy_directory(CNN_GROUND_TRUTH_DIRECTORY) + '/authentic.npy'

def file_exists(file):
  return os.path.exists(file)

# %%
import random
import numpy as np
import os
import threading

lock = threading.Lock()

def iterate_directory(directory, is_tampered):
  list_of_files = os.listdir(directory)
  for file in list_of_files:
    if os.path.isfile(os.path.join(directory, file)) and (file.endswith(".jpg") or file.endswith(".bmp") or file.endswith(".tif")):
      if is_tampered and not cnn_groundtruth_exists(directory, file):
        print("skipping", file, "as it's tampered but no groundtruth file exists")
        continue
      if not file_exists(get_npy_file(directory, file)):
        print("skipping", get_npy_file(directory, file), "as it does not exist")
        continue
      with lock:
        add_to_training_set = np.random.choice([0, 1], p=[0.2, 0.8])                                            # 80% is initially reserved to training set, 20% remaining to test set
        if bool(add_to_training_set):
          append_to_training_set(directory, file, is_tampered)
        else:
          append_to_test_set(directory, file, is_tampered)
    else:
      print("skipping", file, "as it's not a JPG, BMP or TIF file")

def iterate_augmented_directory(directory, is_tampered):
  list_of_files = os.listdir(directory)
  for file in list_of_files:
    if is_tampered and not file_exists(CNN_GROUND_TRUTH_DIRECTORY + "/augment/npy/" + file):                # TODO Les màscares d'augment estan mal generades, els falta el _gt
      print("skipping", directory, "/", file, "as it's tampered but no groundtruth file exists")
      continue
    with lock:
      add_to_training_set = np.random.choice([0, 1], p=[0.2, 0.8])                                            # 80% is initially reserved to training set, 20% remaining to test set
      filename = directory + "/" + file
      if bool(add_to_training_set):
        CNN_TRAINING_SET.append(get_memmap_array_filename(filename))
        filename_to_load = (CNN_GROUND_TRUTH_DIRECTORY + "/augment/npy/" + file) if is_tampered else get_npy_authentic_file()
        CNN_TRAINING_LABEL_SET.append(get_memmap_array_filename(filename_to_load))
      else:
        CNN_TEST_SET.append(get_memmap_array_filename(filename))
        filename_to_load = (CNN_GROUND_TRUTH_DIRECTORY + "/augment/npy/" + file) if is_tampered else get_npy_authentic_file()
        CNN_TEST_LABEL_SET.append(get_memmap_array_filename(filename_to_load))

def append_to_training_set(directory, file, is_tampered):
  CNN_TRAINING_SET.append(get_memmap_array(directory, file))
  if is_tampered:
    CNN_TRAINING_LABEL_SET.append(get_memmap_array_filename(get_cnn_groundtruth_path(directory, file)))
  else:
    CNN_TRAINING_LABEL_SET.append(get_memmap_array_filename(get_npy_authentic_file()))

def append_to_test_set(directory, file, is_tampered):
  CNN_TEST_SET.append(get_memmap_array(directory, file))
  if is_tampered:
    CNN_TEST_LABEL_SET.append(get_memmap_array_filename(get_cnn_groundtruth_path(directory, file)))
  else:
    CNN_TEST_LABEL_SET.append(get_memmap_array_filename(get_npy_authentic_file()))

def get_cnn_groundtruth_path(directory, file):
  final_dir = get_augmented_image_directory(CNN_GROUND_TRUTH_DIRECTORY) if '/augment' in directory else CNN_GROUND_TRUTH_DIRECTORY
  return get_npy_directory(final_dir) + '/' + file[:-4] + '_gt.png.npy'

def cnn_groundtruth_exists(directory, file):
  #print("checking", get_cnn_groundtruth_path(directory, file))
  return os.path.exists(get_cnn_groundtruth_path(directory, file)) # e.g. Tp_S_NNN_S_N_sec00054_sec00055_11341_gt.png does not exist.

def file_exists(file):
  return os.path.exists(file)

def get_memmap_array(directory, file):
  filename = get_npy_file(directory, file)
  return get_memmap_array_filename(filename)

def get_memmap_array_filename(filename):
  return np.load(filename, mmap_mode='r')

def get_augmented_image_directory(directory):
  return directory + "/augment"

# %%
CNN_TRAINING_SET = []
CNN_TRAINING_LABEL_SET = []
CNN_TEST_SET = []
CNN_TEST_LABEL_SET = []

# Populate sets
import concurrent.futures

# Define the directory processing tasks as separate functions
def process_augmented_tampered():
    iterate_augmented_directory(CNN_TAMPERED_DIRECTORY + "/augment/npy", True)

def process_augmented_authentic():
    iterate_augmented_directory(CNN_AUTHENTIC_DIRECTORY + "/augment/npy", False)

def process_tampered():
    iterate_directory(CNN_TAMPERED_DIRECTORY, True)

def process_authentic():
    iterate_directory(CNN_AUTHENTIC_DIRECTORY, False)

# Run each function in a separate thread
with concurrent.futures.ThreadPoolExecutor() as executor:
    futures = [
        executor.submit(process_augmented_tampered),
        executor.submit(process_augmented_authentic),
        executor.submit(process_tampered),
        executor.submit(process_authentic)
    ]
    # Wait for all tasks to complete
    for future in concurrent.futures.as_completed(futures):
        future.result()  # This will raise an exception if any occurred

# At this point all sets are populated
print("train set size: ", len(CNN_TRAINING_SET))
print("train label set size: ", len(CNN_TRAINING_LABEL_SET))
print("test set size : ", len(CNN_TEST_SET))
print("test label set size : ", len(CNN_TEST_LABEL_SET))
# Out:
# skipping Tp_S_NNN_S_N_sec00054_sec00055_11341.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_sec20007_sec20007_02154.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_O_txt00039_txt00042_10831.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRD_S_B_cha00089_ani00013_00409.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRD_S_B_pla20089_nat20043_02353.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRD_S_B_cha20044_nat20042_02432.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_cha10114_nat10114_12181.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_cha00010_art00010_10170.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_cha00085_ani10104_10029.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_nat10164_nat00097_12097.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_art10112_sec00098_11671.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_M_N_nat10164_nat10124_12095.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_B_art00061_sec00099_00527.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_B_cha10125_pla00050_12163.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_B_cha00086_art00012_00406.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_B_ind00025_cha10101_10050.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_B_txt00022_txt00022_20090.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_arc00062_ani00058_11497.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_arc00062_ani00070_11498.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_arc00082_arc00082_00785.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_arc00062_ani00017_11500.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_art20067_arc20001_01873.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_cha10167_cha10208_12368.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_ind10103_ind10104_11552.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_ind00046_ind00046_10893.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_ind00034_art00068_00449.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_ind00048_ind00034_00456.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_N_pla20017_pla20027_01927.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NRN_S_O_cha00035_cha00067_11734.jpg as it's tampered but no groundtruth file exists
# skipping npy as it's not a JPG, BMP or TIF file
# skipping augment as it's not a JPG, BMP or TIF file
# skipping npy as it's not a JPG, BMP or TIF file
# skipping augment as it's not a JPG, BMP or TIF file
# skipping Tp_S_NNN_S_B_pla00019_pla00020_20034.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_ani00047_ani00047_00829.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_ani00055_ani00051_11147.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_arc20013_arc20013_02157.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_art00038_ind00034_01416.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_cha00061_cha00043_11021.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_nat00064_nat00064_00672.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_nat20068_nat20067_01572.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_pla00035_pla00035_01135.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_pla00063_pla00035_00594.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_N_pla00100_ani00079_00540.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_CNN_S_N_art20065_art20065_01870.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_CNN_S_N_cha10114_nat10114_12182.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CNN_S_N_cha0003_cha00003_00323.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_M_N_nat10164_nat00021_12098.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_arc00004_arc00004_11175.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_arc00078_art00092_11881.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_arc00062_ani00005_11499.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_ind00044_sec00007_00453.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_ind00046_ind00046_10892.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_CRN_S_N_cha10206_cha10207_12346.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NND_S_B_nat20026_arc20001_02226.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NND_S_B_art00004_ani00077_01194.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_M_N_nat10164_nat10160_12096.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_S_B_ani00076_ani00077_00196.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_M_N_pla0006_pla00006_01128.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_M_N_sec00054_cha00062_11473.jpg as it's tampered but no groundtruth file exists
# skipping Tp_S_NNN_M_O_nat00045_nat00099_10558.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_nat10145_nat10145_11978.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_O_arc00023_cha00014_10011.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_nat10103_ani00005_10117.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_ind10103_cha10110_11553.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_B_arc00088_arc00088_00308.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_B_art00087_art00087_01010.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_B_ani00097_ani00097_10059.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_B_nat20009_nat20009_01513.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_B_sec00029_nat00029_20113.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_ani00094_ani00094_01256.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_ani00054_ani00054_11129.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_arc00019_arc00019_00239.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_art00036_art00036_00514.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_art00029_art00029_01216.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_art00083_art00083_01391.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_cha00062_cha00062_00381.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_cha00086_cha00086_11403.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_nat00041_nat00041_00655.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_pla00094_pla00094_01191.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_pla00030_pla00030_10951.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_txt00029_txt00029_10832.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_S_N_sec00071_sec00071_00092.tif as it's tampered but no groundtruth file exists
# skipping Tp_S_CNN_S_B_nat00016_nat00016_01000.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CRN_S_N_art00005_art00005_00497.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CRN_S_N_cha10122_nat10123_12168.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CRN_S_N_pla00044_pla00044_10974.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_B_cha00088_txt00068_10182.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_B_sec00072_sec00072_00727.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_arc00092_arc00092_00312.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_arc00087_arc00087_00307.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_arc20087_arc20087_01727.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_cha00084_cha00084_00700.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_ind00080_ind00080_00478.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_ind00074_ind00074_01361.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_cha00046_cha00046_00366.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_cha00045_cha00045_00365.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00059_nat00059_00666.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00086_nat00086_00681.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00011_nat00011_11057.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00092_nat00092_00684.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00012_nat00012_11055.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_nat00061_nat00061_00668.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_pla00015_pla00015_00554.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_pla00006_pla00006_00546.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_pla00066_pla00066_11218.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_sec00085_sec00085_00816.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_sec00063_sec00063_00743.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_L_B_arc20049_arc20049_02480.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NNN_S_N_sec00093_sec00093_00756.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_N_arc20052_arc20052_02478.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_B_arc20062_arc20062_02482.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_B_arc20061_arc20061_02481.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_N_arc00004_nat00062_11177.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_N_sec20052_sec20052_02130.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_M_O_sec20032_sec20032_01622.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_B_arc20016_arc20016_02199.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_B_ind00055_ind00055_01344.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_B_arc20100_arc20100_02185.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_N_cha10002_cha10001_20094.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_N_cha00015_cha00015_11154.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRD_S_N_art00076_art00076_11709.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_cha00033_cha00033_11015.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_arc00004_nat00062_11176.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_ani00083_ani00083_10040.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_NRN_M_N_nat00089_pla10118_10583.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_ind00091_ind00091_10648.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_arc00086_arc00086_00306.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_nat00090_nat00090_10575.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_pla00042_pla00042_10976.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_nat00077_nat00077_10574.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_nat00089_nat00089_10576.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_M_N_ind00091_ind00091_10647.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_cha10122_nat10139_12166.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CRD_M_N_arc10116_arc10116_10762.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CRD_S_B_sec20007_sec20007_01442.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_nat00035_nat00035_00649.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CRD_M_N_ind00091_ind00091_10645.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_txt00051_txt00051_10376.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_nat00060_nat00060_00667.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_arc00020_arc00020_00240.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_B_cha00025_cha00025_00345.tif as it's tampered but no groundtruth file exists
# skipping Tp_D_CRD_M_N_ind00091_ind00091_10646.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_cha10122_nat10124_12167.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CNN_S_N_cha10122_nat00059_12169.jpg as it's tampered but no groundtruth file exists
# skipping Tp_D_CRN_L_N_art00028_art00028_11282.jpg as it's tampered but no groundtruth file exists
# train set size:  13021
# train label set size:  13021
# test set size :  3280
# test label set size :  3280

# %% [markdown]
# **BINARY CLASSIFIER**

# %%
# Prepare for training
y = []
for i in range(len(CNN_TRAINING_LABEL_SET)):
  if 255 in CNN_TRAINING_LABEL_SET[i]:
      y.append(1) # Tampering
  else:
      y.append(0) # Authentic

instances_count = len(CNN_TRAINING_SET)

x = np.array(CNN_TRAINING_SET)
y = np.array(y)

print("size of training set", len(x))
print("size of training label set", len(y))
# Out:
# size of training set 13021
# size of training label set 13021

# %%
from functools import partial
import tensorflow as tf

DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same", activation="relu", kernel_initializer="he_normal")

shape = [256, 384, 3]

model = tf.keras.Sequential([
   DefaultConv2D(filters=32, kernel_size=5, strides=1, input_shape=shape),
   tf.keras.layers.BatchNormalization(),
   tf.keras.layers.MaxPool2D(),
   DefaultConv2D(filters=64),
   tf.keras.layers.MaxPool2D(),
   DefaultConv2D(filters=64),
   tf.keras.layers.MaxPool2D(),
   tf.keras.layers.GlobalAveragePooling2D(),
   tf.keras.layers.Dense(units=64, activation="relu", kernel_initializer="he_normal"),
   tf.keras.layers.Dropout(0.5),
   tf.keras.layers.Dense(units=64, activation="relu", kernel_initializer="he_normal"),
   tf.keras.layers.Dropout(0.5),
   tf.keras.layers.Dense(units=1, activation="sigmoid")
])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, min_delta=0.001)

num_authentic = np.sum(y == 0)
num_tampered = np.sum(y == 1)
all_instances = num_authentic + num_tampered
weight_authentic = all_instances / (2*num_authentic)
weight_tampered = all_instances / (2*num_tampered)

class_weights = {
    0: weight_authentic,
    1: weight_tampered
}

history = model.fit(x, y, epochs=100, validation_split=0.2, callbacks=[early_stopping], shuffle=True, class_weight=class_weights)
# Out:
# Epoch 1/100
# 326/326 [==============================] - 501s 2s/step - loss: 0.7142 - accuracy: 0.5445 - val_loss: 0.8226 - val_accuracy: 0.1121
# Epoch 2/100
# 326/326 [==============================] - 494s 2s/step - loss: 0.6843 - accuracy: 0.5517 - val_loss: 0.8377 - val_accuracy: 0.1121
# Epoch 3/100
# 326/326 [==============================] - 465s 1s/step - loss: 0.6795 - accuracy: 0.5524 - val_loss: 0.7928 - val_accuracy: 0.1121
# Epoch 4/100
# 326/326 [==============================] - 430s 1s/step - loss: 0.6751 - accuracy: 0.5580 - val_loss: 0.7725 - val_accuracy: 0.1144
# Epoch 5/100
# 326/326 [==============================] - 429s 1s/step - loss: 0.6731 - accuracy: 0.5709 - val_loss: 0.8530 - val_accuracy: 0.1566
# Epoch 6/100
# 326/326 [==============================] - 431s 1s/step - loss: 0.6645 - accuracy: 0.5874 - val_loss: 0.6832 - val_accuracy: 0.6591
# Epoch 7/100
# 326/326 [==============================] - 431s 1s/step - loss: 0.6541 - accuracy: 0.6141 - val_loss: 0.7011 - val_accuracy: 0.5992
# Epoch 8/100
# 326/326 [==============================] - 430s 1s/step - loss: 0.6478 - accuracy: 0.6262 - val_loss: 0.7844 - val_accuracy: 0.4514
# Epoch 9/100
# 326/326 [==============================] - 429s 1s/step - loss: 0.6387 - accuracy: 0.6454 - val_loss: 0.9343 - val_accuracy: 0.3463
# Epoch 10/100
# 326/326 [==============================] - 429s 1s/step - loss: 0.6325 - accuracy: 0.6470 - val_loss: 0.8839 - val_accuracy: 0.4157
# Epoch 11/100
# 326/326 [==============================] - 430s 1s/step - loss: 0.6257 - accuracy: 0.6598 - val_loss: 0.8151 - val_accuracy: 0.4691

# %%
model.save("/content/gdrive/MyDrive/TFM/FINAL___binary_classifier_model_for_tampering_detection_based_on_pfa.keras")

# %%
# Plot training and validation losses so model convergence and overfitting can be visualized

import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
instances = np.array(CNN_TEST_SET)
preds = model.predict(instances)
# Out:
# 103/103 [==============================] - 43s 420ms/step

# %%
y_test = []
for i in range(len(CNN_TEST_LABEL_SET)):
    if 255 in CNN_TEST_LABEL_SET[i]:
        y_test.append(1) # Tampering
    else:
        y_test.append(0) # Authentic

y_test = np.array(y_test)

print("train set size: ", len(x))
print("test set size : ", len(CNN_TEST_SET))
# Out:
# train set size:  13021
# test set size :  3280

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Calculate precision, recall, and thresholds
precisions, recalls, thresholds = precision_recall_curve(y_test, preds)

# Plot the Precision-Recall Curve against thresholds
threshold = 0.49
label = "Threshold = " + str(threshold)
plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
plt.vlines(threshold, 0, 1.0, "k", "dotted", label=label)

# Add axis titles
plt.xlabel("Threshold")
plt.ylabel("Precision and Recall")

# Add a legend
plt.legend(loc="best")

# Show the plot
plt.title("Precision and Recall vs Threshold")
plt.grid()
plt.show()

# %%
binary_classes = (preds >= threshold).astype(int)
binary_classes = binary_classes.flatten()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
cm = confusion_matrix(y_test, binary_classes)

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("precision     : ", round(precision_score(y_test, binary_classes, pos_label=1)*100,2), "%")
print("recall        : ", round(recall_score(y_test, binary_classes, pos_label=1)*100,2), "%")
print("f1 score      : ", round(f1_score(y_test, binary_classes, pos_label=1),2))
# Out:
# precision     :  58.45 %
# recall        :  57.57 %
# f1 score      :  0.58

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, preds.ravel())

# Calculate the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# **LOCALIZER**

# %%
import tensorflow as tf
from functools import partial

DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same", activation="relu", kernel_initializer="he_normal")

shape = (256, 384, 3)

localizer_model = tf.keras.Sequential([
    # Downsampling path
    DefaultConv2D(filters=32, kernel_size=5, strides=1, input_shape=shape),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(),  # Downsample by 2x

    DefaultConv2D(filters=64),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(),  # Downsample by another 2x

    DefaultConv2D(filters=128),  # Extract deeper features (was 64)
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=64),


    # Upsampling path
   tf.keras.layers.Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding="same", activation="relu"),  # Upsample by 2x
   tf.keras.layers.BatchNormalization(),

   tf.keras.layers.Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding="same", activation="relu"),  # Upsample by 2x
   tf.keras.layers.BatchNormalization(),

    # Output layer
   tf.keras.layers.Conv2D(filters=1, kernel_size=1, activation="sigmoid")  # Single-channel output
])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

localizer_model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=['accuracy'])

# %%
# Prepare for training
x = np.array(CNN_TRAINING_SET)
y = np.array(CNN_TRAINING_LABEL_SET)
y = np.expand_dims(y, axis=-1)
y = y // 255

print("size of training set", len(x))
print("size of training label set", len(y))
# Out:
# size of training set 13021
# size of training label set 13021

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, min_delta=0.001)

# Get unique values and their counts
unique, counts = np.unique(y, return_counts=True)

# Assign the counts to num_authentic and num_tampered based on the unique values
num_authentic = counts[unique == 0][0] if 0 in unique else 0
num_tampered = counts[unique == 1][0] if 1 in unique else 0

all_instances = num_authentic + num_tampered

weight_authentic = all_instances / (2*num_authentic)
weight_tampered = all_instances / (2*num_tampered)

class_weights = {
    0: weight_authentic,
    1: weight_tampered
}

history_localizer = localizer_model.fit(x, y, epochs=100, validation_split=0.2, callbacks=[early_stopping], shuffle=True, class_weight=class_weights)
# Out:
# Epoch 1/100
# 326/326 [==============================] - 1066s 3s/step - loss: 0.7291 - accuracy: 0.4061 - val_loss: 0.7937 - val_accuracy: 0.5711
# Epoch 2/100
# 326/326 [==============================] - 1058s 3s/step - loss: 0.7233 - accuracy: 0.3675 - val_loss: 0.7652 - val_accuracy: 0.1540
# Epoch 3/100
# 326/326 [==============================] - 1068s 3s/step - loss: 0.7214 - accuracy: 0.4464 - val_loss: 0.6923 - val_accuracy: 0.6955
# Epoch 4/100
# 326/326 [==============================] - 1071s 3s/step - loss: 0.7200 - accuracy: 0.4479 - val_loss: 0.7634 - val_accuracy: 0.1609
# Epoch 5/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.7189 - accuracy: 0.4028 - val_loss: 0.8133 - val_accuracy: 0.1393
# Epoch 6/100
# 326/326 [==============================] - 1042s 3s/step - loss: 0.7182 - accuracy: 0.3812 - val_loss: 0.7017 - val_accuracy: 0.3365
# Epoch 7/100
# 326/326 [==============================] - 1042s 3s/step - loss: 0.7167 - accuracy: 0.3876 - val_loss: 0.7124 - val_accuracy: 0.5015
# Epoch 8/100
# 326/326 [==============================] - 1043s 3s/step - loss: 0.7175 - accuracy: 0.4899 - val_loss: 0.7989 - val_accuracy: 0.1207
# Epoch 9/100
# 326/326 [==============================] - 1044s 3s/step - loss: 0.7141 - accuracy: 0.3479 - val_loss: 0.8216 - val_accuracy: 0.1731
# Epoch 10/100
# 326/326 [==============================] - 1043s 3s/step - loss: 0.7126 - accuracy: 0.3573 - val_loss: 0.7173 - val_accuracy: 0.3222
# Epoch 11/100
# 326/326 [==============================] - 1043s 3s/step - loss: 0.7115 - accuracy: 0.3970 - val_loss: 0.4694 - val_accuracy: 0.9173
# Epoch 12/100
# 326/326 [==============================] - 1044s 3s/step - loss: 0.7092 - accuracy: 0.4110 - val_loss: 0.6824 - val_accuracy: 0.5695
# Epoch 13/100
# 326/326 [==============================] - 1044s 3s/step - loss: 0.7088 - accuracy: 0.3983 - val_loss: 0.7258 - val_accuracy: 0.7176
# Epoch 14/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.7079 - accuracy: 0.3785 - val_loss: 0.6803 - val_accuracy: 0.5971
# Epoch 15/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.7060 - accuracy: 0.4261 - val_loss: 0.6973 - val_accuracy: 0.3558
# Epoch 16/100
# 326/326 [==============================] - 1044s 3s/step - loss: 0.7050 - accuracy: 0.3949 - val_loss: 0.7033 - val_accuracy: 0.3719
# Epoch 17/100
# 326/326 [==============================] - 1042s 3s/step - loss: 0.7042 - accuracy: 0.3829 - val_loss: 0.8640 - val_accuracy: 0.1742
# Epoch 18/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.7033 - accuracy: 0.3888 - val_loss: 0.6574 - val_accuracy: 0.4355
# Epoch 19/100
# 326/326 [==============================] - 1043s 3s/step - loss: 0.7020 - accuracy: 0.3844 - val_loss: 0.7619 - val_accuracy: 0.3356
# Epoch 20/100
# 326/326 [==============================] - 1044s 3s/step - loss: 0.7010 - accuracy: 0.4004 - val_loss: 0.6463 - val_accuracy: 0.4537
# Epoch 21/100
# 326/326 [==============================] - 1046s 3s/step - loss: 0.6993 - accuracy: 0.4047 - val_loss: 0.7218 - val_accuracy: 0.3178
# Epoch 22/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.6985 - accuracy: 0.4117 - val_loss: 0.7513 - val_accuracy: 0.2521
# Epoch 23/100
# 326/326 [==============================] - 1047s 3s/step - loss: 0.6974 - accuracy: 0.4174 - val_loss: 0.7198 - val_accuracy: 0.3551
# Epoch 24/100
# 326/326 [==============================] - 1048s 3s/step - loss: 0.6968 - accuracy: 0.4261 - val_loss: 0.6911 - val_accuracy: 0.7755
# Epoch 25/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.6952 - accuracy: 0.4731 - val_loss: 0.8414 - val_accuracy: 0.2249
# Epoch 26/100
# 326/326 [==============================] - 1045s 3s/step - loss: 0.6929 - accuracy: 0.3815 - val_loss: 0.7899 - val_accuracy: 0.2943

# %%
localizer_model.save("/content/gdrive/MyDrive/TFM/FINAL___localizer_model_for_tampering_detection_based_on_pfa.keras")

# %%
# Plot training and validation losses so model convergence and overfitting can be visualized

import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history_localizer.history['loss'], label='Training Loss')
plt.plot(history_localizer.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
instances = np.array(CNN_TEST_SET)
preds = localizer_model.predict(instances)
# Out:
# 103/103 [==============================] - 102s 991ms/step

# %%
y_test = np.array(CNN_TEST_LABEL_SET)
y_test = np.expand_dims(y_test, axis=-1)
y_test = y_test // 255

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# Calculate precision, recall, and thresholds
precisions, recalls, thresholds = precision_recall_curve(y_test.ravel(), preds.ravel())

# Plot the Precision-Recall Curve against thresholds
threshold = 0.57
label = "Threshold = " + str(threshold)
plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
plt.vlines(threshold, 0, 1.0, "k", "dotted", label=label)

# Add axis titles
plt.xlabel("Threshold")
plt.ylabel("Precision and Recall")

# Add a legend
plt.legend(loc="best")

# Show the plot
plt.title("Precision and Recall vs Threshold")
plt.grid()
plt.show()

# %%
binary_classes = (preds >= threshold).astype(int)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate 10 random indices
random_indices = np.random.choice(len(binary_classes), 10, replace=False)

# Set up a plot with 10 rows and 2 columns
fig, axes = plt.subplots(10, 2, figsize=(10, 30))  # Adjust figure size as needed

for i, idx in enumerate(random_indices):
    predicted_image = binary_classes[idx].squeeze()
    truth_image = y_test[idx].squeeze()

    # Display predicted image
    axes[i, 0].imshow(predicted_image, cmap='gray')
    axes[i, 0].set_title(f"Predicted (Index {idx})")
    axes[i, 0].axis('off')

    # Display truth image
    axes[i, 1].imshow(truth_image, cmap='gray')
    axes[i, 1].set_title(f"Ground Truth (Index {idx})")
    axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
binary_classes = binary_classes.flatten()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
cm = confusion_matrix(y_test.ravel(), binary_classes.ravel())

# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("precision     : ", round(precision_score(y_test.ravel(), binary_classes.ravel(), pos_label=1)*100,2), "%")
print("recall        : ", round(recall_score(y_test.ravel(), binary_classes.ravel(), pos_label=1)*100,2), "%")
print("f1 score      : ", round(f1_score(y_test.ravel(), binary_classes.ravel(), pos_label=1),2))
# Out:
# precision     :  10.0 %
# recall        :  7.93 %
# f1 score      :  0.09

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test.ravel(), preds.ravel())

# Calculate the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, color='blue', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
